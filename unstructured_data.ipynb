# %%
import pandas as pd
from sklearn.datasets import load_wine
from sklearn.model_selection import train_test_split
from sklearn.cluster import KMeans
from sklearn.metrics import silhouette_score

# %%
wine = load_wine(as_frame=True)
X = wine.data

# %%
X_train, X_test = train_test_split(
    X,
    test_size=0.2,
    random_state=42
)

# %%
model = KMeans(n_clusters=3, random_state=42,n_init="auto")
model.fit(X_train)
# Out:
# KMeans(n_clusters=3, random_state=42)

# %%
train_cluster = model.predict(X_train)
score = silhouette_score(X_train, train_cluster)
print(f"Silhousette coefficient (Val Metric):{score:.4f}")
# Out:
# Silhousette coefficient (Val Metric):0.5684

# %%
X.iloc[[0]]
# Out:
#    alcohol  malic_acid   ash  alcalinity_of_ash  magnesium  total_phenols  \
# 0    14.23        1.71  2.43               15.6      127.0            2.8
#
#    flavanoids  nonflavanoid_phenols  proanthocyanins  color_intensity   hue  \
# 0        3.06                  0.28             2.29             5.64  1.04
#
#    od280/od315_of_diluted_wines  proline
# 0                          3.92   1065.0

# %%
sample=X.iloc[[0]]
predicted_cluster = model.predict(sample)
print(f"Empirical Inference Cluster Assignment: {predicted_cluster[0]}")
# Out:
# Empirical Inference Cluster Assignment: 1
